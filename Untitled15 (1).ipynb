# %%
# !pip install --upgrade openai

# %%
# !pip install pandasai

# %%
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 29.3 MB/s eta 0:00:00
# ...

# %%
# %pip install -qU langchain langchain-openai langchain-community langchain-experimental pandas

# %%
import openai

# %% [markdown]
# Cleaning of Dataset using PandasAI library. Reasons for choosing it has following features:
#
#
# Natural language querying: Ask questions to your data in natural language.
# Data visualization: Generate graphs and charts to visualize your data.
# Data cleansing: Cleanse datasets by addressing missing values.
# Feature generation: Enhance data quality through feature generation.
# Data connectors: Connect to various data sources like CSV, XLSX, PostgreSQL, MySQL, BigQuery, Databrick, Snowflake, etc.

# %%
from pandasai import SmartDataframe
from pandasai.llm import OpenAI

# %%
llm = OpenAI(api_token="YOUR_KEY")

# %%
import pandas as pd  # for storing text and embeddings data

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/bicycleAI/Airline ID to.csv')
df_2 = pd.read_csv('/content/drive/MyDrive/bicycleAI/Flight.csv')

# %%
df_2.head()
# Out:
#    airlie_id  flght#         departure_dt           arrival_dt  dep_time  \
# 0          6    2637  2023-06-26 00:11:20  2023-10-30 21:30:16  13:48:45
# 1          5    6966  2023-04-27 21:36:15  2023-10-27 13:13:48  14:05:17
# 2         12    5670  2023-03-31 15:08:52  2023-12-30 10:58:37  12:47:06
# 3          1    6203  2023-08-04 16:59:58  2023-03-01 18:34:01  02:46:37
# 4          8    6134  2023-03-07 01:08:36  2023-03-30 04:51:17  13:46:28
#
#   arrivl_time booking_cd  passngr_nm  seat_no     class  ...       pilot  \
# 0    21:01:47       BQLF  Name_BANUL  SeatTWV   Economy  ...  Pilot_EYZH
# 1    09:12:24       BZIL  Name_KANHR  SeatIGS   Economy  ...  Pilot_OKTY
# 2    22:28:40       BQPB  Name_ECVFX  SeatJUH   Economy  ...  Pilot_UQZR
# 3    10:53:22       BRPJ  Name_UEUYB  SeatUUC   Economy  ...  Pilot_OLHE
# 4    07:10:26       BSDG  Name_CDWZA  SeatLTY  Business  ...  Pilot_DJHP
#
#   cabin_crew  inflight_ent     meal_option           wifi window_seat  \
# ...

# %%
df_1.head()
# Out:
#    airlie_id        airline_name
# 0          1    American Airline
# 1          2     Delta Air Lines
# 2          3     United Airlines
# 3          4  Southwest Airlines
# 4          5     JetBlue Airways

# %%
sdf = SmartDataframe(df_1, config={"llm": llm})

# %%
cleaning_response_1=sdf.chat("Are there any missing values present in the data?")

# %%
print(cleaning_response_1)
# Out:
# The number of missing values in the data is: 0

# %%
final_df_1=sdf.chat("Rename columns to more intuitive, business-friendly names for easier querying.")

# %%
df_1.head()
# Out:
#    airline_id        airline_name
# 0           1    American Airline
# 1           2     Delta Air Lines
# 2           3     United Airlines
# 3           4  Southwest Airlines
# 4           5     JetBlue Airways

# %%
sdf_2= SmartDataframe(df_2,config={"llm": llm} )

# %%
cleaning_response_df_2_1=sdf_2.chat("Are there any missing values present in the data?")
print(cleaning_response_df_2_1)
# Out:
# 0

# %%
reponse_note =sdf_2.chat("Identify and correct inconsistencies within each column in the dataset.")

# %%
print(sdf_2.last_code_generated)
# Out:
# None

# %%
sdf_2.chat("Rename columns to more intuitive, business-friendly names for easier querying. keeping all in small letters")
# Out:
# 'Columns renamed successfully.'

# %%
df_2.head()
# Out:
#    airline_id  flight_number   departure_datetime     arrival_datetime  \
# 0           6           2637  2023-06-26 00:11:20  2023-10-30 21:30:16
# 1           5           6966  2023-04-27 21:36:15  2023-10-27 13:13:48
# 2          12           5670  2023-03-31 15:08:52  2023-12-30 10:58:37
# 3           1           6203  2023-08-04 16:59:58  2023-03-01 18:34:01
# 4           8           6134  2023-03-07 01:08:36  2023-03-30 04:51:17
#
#   departure_time arrival_time booking_code passenger_name seat_number  \
# 0       13:48:45     21:01:47         BQLF     NAME_BANUL     SEATTWV
# 1       14:05:17     09:12:24         BZIL     NAME_KANHR     SEATIGS
# 2       12:47:06     22:28:40         BQPB     NAME_ECVFX     SEATJUH
# 3       02:46:37     10:53:22         BRPJ     NAME_UEUYB     SEATUUC
# 4       13:46:28     07:10:26         BSDG     NAME_CDWZA     SEATLTY
#
#       class  ...       pilot cabin_crew  inflight_entertainment  \
# ...

# %%
from langchain_openai import ChatOpenAI

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"

# %%
langchain_llm = ChatOpenAI(model="gpt-4-0125-preview", temperature=0)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_experimental.tools import PythonAstREPLTool

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
from langchain_community.vectorstores import FAISS
from langchain_core.example_selectors import SemanticSimilarityExampleSelector
from langchain_openai import OpenAIEmbeddings

# %%
import sqlite3



# Step 2: Connect to SQLite database
conn = sqlite3.connect('your_database.db')

# Step 3: Define schema and create tables
table_name1 = 'table1'
table_name2 = 'table2'

df_1.to_sql(table_name1, conn, if_exists='replace', index=False)
df_2.to_sql(table_name2, conn, if_exists='replace', index=False)

# Step 4: Commit changes and close connection
conn.commit()
conn.close()

print(f"CSV files have been successfully converted to SQL database 'your_database.db'.")
# Out:
# CSV files have been successfully converted to SQL database 'your_database.db'.

# %% [markdown]
# SQL

# %%
from langchain_community.utilities import SQLDatabase


# Provide the correct path to your SQLite database file
db_path = "/content/your_database.db"

# Create a SQLDatabase object from the SQLite database file
db = SQLDatabase.from_uri(f"sqlite:///{db_path}")

print(db)
print(db.get_usable_table_names())
# print(db.get_usable_table_names())
# db.run("SELECT * FROM Artist LIMIT 10;")
# Out:
# ...
# ['table1', 'table2']

# %%
from langchain_community.agent_toolkits import create_sql_agent

agent_executor = create_sql_agent(langchain_llm, db=db, agent_type="openai-tools", verbose=True)

# %%
response=agent_executor.invoke(
    {
        "input": "What is the airline with highest number of flights?"
    }
)
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with ``
#
#
# table1, table2
# Invoking: `sql_db_schema` with `{'table_names': 'table1'}`
#
#
#
# CREATE TABLE table1 (
# 	airline_id INTEGER,
# 	airline_name TEXT
# )
#
# /*
# 3 rows from table1 table:
# airline_id	airline_name
# 1	American Airline
# 2	Delta Air Lines
# 3	United Airlines
# */
# Invoking: `sql_db_schema` with `{'table_names': 'table2'}`
#
#
#
# CREATE TABLE table2 (
# 	airline_id INTEGER,
# 	flight_number INTEGER,
# 	departure_datetime TEXT,
# 	arrival_datetime TEXT,
# 	departure_time TEXT,
# 	arrival_time TEXT,
# 	booking_code TEXT,
# 	passenger_name TEXT,
# 	seat_number TEXT,
# 	class TEXT,
# 	fare REAL,
# 	extras TEXT,
# 	loyalty_points INTEGER,
# 	status TEXT,
# 	gate TEXT,
# 	terminal TEXT,
# 	baggage_claim TEXT,
# 	duration_hours REAL,
# 	layovers INTEGER,
# 	layover_locations TEXT,
# 	aircraft_type TEXT,
# 	pilot TEXT,
# 	cabin_crew TEXT,
# 	inflight_entertainment TEXT,
# ...

# %%
#fewshot prompting
examples = [
    {"input": "Calculate the average flight delay per airline.",
     "query": "SELECT table1.AirlineName, AVG((strftime('%s', table2.DepartureTime)-strftime('%s', SUBSTR(table2.DepartureDate, 12)))/60 ) AS AverageDelayInMinutes FROM table1 JOIN table2 ON table1.AirlineID = table2.AirlineID GROUP BY table1.AirlineName;"
    },

]

# %%
#using a SemanticSimilarityExampleSelector, which will perform a semantic search using the embeddings and vector store we configure to find the examples most similar to our input
example_selector = SemanticSimilarityExampleSelector.from_examples(
    examples,
    OpenAIEmbeddings(),
    FAISS,
    k=5,
    input_keys=["input"],
)

# %%
# Using FewShotPromptTemplate, which takes our example selector, an example prompt for formatting each example, and a string prefix and suffix to put before and after our formatted examples
from langchain_core.prompts import (
    ChatPromptTemplate,
    FewShotPromptTemplate,
    MessagesPlaceholder,
    PromptTemplate,
    SystemMessagePromptTemplate,
)

system_prefix = """You are an agent designed to interact with a SQL database.
Given an input question, create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer.
Unless the user specifies a specific number of examples they wish to obtain, always limit your query to at most {top_k} results.
You can order the results by a relevant column to return the most interesting examples in the database.
Never query for all the columns from a specific table, only ask for the relevant columns given the question.
You have access to tools for interacting with the database.
Only use the given tools. Only use the information returned by the tools to construct your final answer.
To find the locations visited you can also use Layovers.
You can use your knowledge to actually name the locations from their shortforms.
Use only the  DepartureDate's and ArrivalDate's time part to calculate delays.

You MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.
You MUST always give ouput based on the given database
DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.

If the question does not seem related to the database, just return "I don't know" as the answer.

Here are some examples of user inputs and their corresponding SQL queries:"""

few_shot_prompt = FewShotPromptTemplate(
    example_selector=example_selector,
    example_prompt=PromptTemplate.from_template(
        "User input: {input}\nSQL query: {query}"
    ),
    input_variables=["input", "dialect", "top_k"],
    prefix=system_prefix,
    suffix="",
)

# %%
#Since our prompt should be a chat prompt with a human message template and an agent_scratchpad MessagesPlaceholder
full_prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessagePromptTemplate(prompt=few_shot_prompt),
        ("human", "{input}"),
        MessagesPlaceholder("agent_scratchpad"),
    ]
)

# %%
# Provide the correct path to your SQLite database file
db_path = "/content/your_database.db"

# Create a SQLDatabase object from the SQLite database file
db = SQLDatabase.from_uri(f"sqlite:///{db_path}")

# %%
agent_llm = create_sql_agent(
    llm=langchain_llm,
    db=db,
    prompt=full_prompt,
    verbose=True,
    agent_type="openai-tools",
)

# %%
def display_chat_history(messages):
    for message in messages:
        print(f"{message['role'].capitalize()}: {message['content']}")

def get_assistant_response(messages):
    # Assuming `agent_llm` is defined elsewhere
    # Find the most recent user input
    user_input = next((message["content"] for message in reversed(messages) if message["role"] == "user"), None)
    if user_input is None:
        return "I'm sorry, I couldn't find your question."

    # Invoke the agent_llm model with the input query
    response = agent_llm.invoke({"input": user_input})

    # Extract and return the recommended airline from the response
    answer = response["output"]

    # Check if the response is the same as the previous one
    if messages and messages[-1]["role"] == "assistant" and messages[-1]["content"] == answer:
        return "I'm sorry, I couldn't find an answer to that."

    return answer

messages = [{"role": "assistant", "content": "How can I help?"}]

while True:
    display_chat_history(messages)

    user_input = input("User: ")
    messages.append({"role": "user", "content": user_input})  # Append user input as a dictionary

    assistant_response = get_assistant_response(messages)
    messages.append({"role": "assistant", "content": assistant_response})
# Out:
# Assistant: How can I help?
#
#
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# table1, table2
# Invoking: `sql_db_schema` with `{'table_names': 'Bookings,Airlines'}`
#
#
# Error: table_names {'Bookings', 'Airlines'} not found in database
# Invoking: `sql_db_list_tables` with `{}`
#
#
# table1, table2
# Invoking: `sql_db_schema` with `{'table_names': 'table1, table2'}`
#
#
#
# CREATE TABLE table1 (
# 	airline_id INTEGER,
# 	airline_name TEXT
# )
#
# /*
# 3 rows from table1 table:
# airline_id	airline_name
# 1	American Airline
# 2	Delta Air Lines
# 3	United Airlines
# */
#
#
# CREATE TABLE table2 (
# 	airline_id INTEGER,
# 	flight_number INTEGER,
# 	departure_datetime TEXT,
# 	arrival_datetime TEXT,
# 	departure_time TEXT,
# 	arrival_time TEXT,
# 	booking_code TEXT,
# 	passenger_name TEXT,
# 	seat_number TEXT,
# 	class TEXT,
# 	fare REAL,
# 	extras TEXT,
# 	loyalty_points INTEGER,
# 	status TEXT,
# 	gate TEXT,
# 	terminal TEXT,
# ...

# %% [markdown]
# Identify patterns in booking cancellations. Are there specific days or airlines with unusually high cancellation rates?

# %%
def display_chat_history(messages):
    for message in messages:
        print(f"{message['role'].capitalize()}: {message['content']}")

# %%
def get_assistant_response(messages):
    # Invoke the agent_llm model with the input query
    response = agent_llm.invoke({"input": messages})

    # Extract and return the recommended airline from the response
    answer = response["output"]
    return answer
# def get_assistant_response(messages):
#     r = client.chat.completions.create(
#         model="gpt-3.5-turbo",
#         messages=[{"role": m["role"], "content": m["content"]} for m in messages],
#     )
#     response = r.choices[0].message.content
#     return response

# %%
messages = [{"role": "assistant", "content": "How can I help?"}]

# %%
while True:
    display_chat_history(messages)

    user_input = input("User: ")
    messages.append(user_input)

    assistant_response = get_assistant_response(messages)
    messages.append({"role": "assistant", "content": assistant_response})
# Out:
# Assistant: How can I help?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-334-ac4e77a81000> in <cell line: 1>()
#       1 while True:
# ----> 2     display_chat_history(messages)
#       3
#       4     user_input = input("User: ")
#       5     messages.append(user_input)
#
# <ipython-input-322-c471e30a6280> in display_chat_history(messages)
#       1 def display_chat_history(messages):
#       2     for message in messages:
# ----> 3         print(f"{message['role'].capitalize()}: {message['content']}")
#
# TypeError: string indices must be integers

# %%
gr.ChatInterface(recomm).launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://5737eae33b042d0567.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5737eae33b042d0567.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
agent_llm.invoke(
    {
        "input": "If someone wants to reach his or her destination as soon as possible, which airline would be recommended?"
    }
)
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with ``
#
#
# table1, table2
# Invoking: `sql_db_schema` with `{'table_names': 'table1,table2'}`
#
#
#
# CREATE TABLE table1 (
# 	"AirlineID" INTEGER,
# 	"AirlineName" TEXT
# )
#
# /*
# 3 rows from table1 table:
# AirlineID	AirlineName
# 1	American Airline
# 2	Delta Air Lines
# 3	United Airlines
# */
#
#
# CREATE TABLE table2 (
# 	"AirlineID" INTEGER,
# 	"FlightNumber" INTEGER,
# 	"DepartureDate" TEXT,
# 	"ArrivalDate" TEXT,
# 	"DepartureTime" TEXT,
# 	"ArrivalTime" TEXT,
# 	"BookingCode" TEXT,
# 	"PassengerName" TEXT,
# 	"SeatNumber" TEXT,
# 	"Class" TEXT,
# 	"Fare" REAL,
# 	"Extras" TEXT,
# 	"LoyaltyPoints" INTEGER,
# 	"Status" TEXT,
# 	"Gate" TEXT,
# 	"Terminal" TEXT,
# 	"BaggageClaim" TEXT,
# 	"FlightDurationHours" REAL,
# 	"NumberOfLayovers" INTEGER,
# 	"LayoverLocations" TEXT,
# 	"AircraftType" TEXT,
# 	"PilotName" TEXT,
# 	"CabinCrewNames" TEXT,
# 	"InflightEntertainmentAvailable" TEXT,
# ...

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 3.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 46.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=073f5cabbf6260102486557fbabb5080d0391244b7ebfa381376dab927920fda
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# ...

# %%
import gradio as gr
